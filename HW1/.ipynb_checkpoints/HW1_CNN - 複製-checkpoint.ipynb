# %%
# importing the libraries
import pandas as pd
import numpy as np

# for reading and displaying images
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline

# for evaluating the model
from sklearn.metrics import accuracy_score
from tqdm import tqdm

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout, MSELoss
from torch.optim import Adam, SGD, lr_scheduler

from skimage.transform import resize
from numpy import asarray
from torch.utils.data import Dataset, DataLoader

# %%
# loading dataset
train_data = pd.read_csv('./train.csv')
test_data = pd.read_csv('./test.csv')

sample_submission = pd.read_csv('sample_submission.csv')

train_data.head()
# Out:
#                                 track     views country     score
# 0  normalize_5s_intro_thc1MtNagC8.wav  38319601     NaN  0.676471
# 1  normalize_5s_intro_Wo2qUD1g7xM.wav  71940972      VN  0.666667
# 2  normalize_5s_intro_3ObVN3QQiZ8.wav  28548855      FR  0.447368
# 3  normalize_5s_intro_S-zQJFRX5Fg.wav    310197     NaN  0.876712
# 4  normalize_5s_intro_SyZOAgXiPMw.wav   1283578     NaN  0.325000

# %%
# loading training images
def get_data():
    train_img = []
    for img_name in tqdm(train_data['track']):
        # defining the image path
        image_path = './img/' + str(img_name) + '.jpg'
        # reading the image
        img = imread(image_path)
        #img = resize(img, (28, 28))
        img = asarray(img)
        # converting the type of pixel to float 32
        img = img.astype('float32')
         # normalizing the pixel values
        img /= 255.0
        # appending the image into the list
        train_img.append(img)

    # converting the list to numpy array
    train_x = np.array(train_img)
    # defining the target
    train_y = np.array(train_data['score'].values)
    
    # converting training images into torch format
    train_x = train_x.reshape(220, 3, 220, 338)
    train_x  = torch.from_numpy(train_x)

    # converting the target into torch format
    train_y = train_y.astype(float);
    train_y = torch.from_numpy(train_y)

    # shape of training data
    train_x.shape, train_y.shape
    
    #print('get_data()')
    #print(train_x)
    #print(train_y)
    
    return train_x, train_y

# %%
class myDataset(Dataset):
    def __init__(self):
        self.audio_img, self.audio_label = get_data()
        print("> Found %d audios..." % (len(self.audio_img)))

    def __getitem__(self, idx):
        self.feature = self.audio_img[idx]
        self.label = self.audio_label[idx]
        #print(self.feature)
        #print(self.label)
        return self.feature, self.label

    def __len__(self):
        return len(self.audio_img)

# %%
class Net(Module):   
    def __init__(self):
        super(Net, self).__init__()

        self.cnn_layers = Sequential(
            # Defining a 2D convolution layer
            Conv2d(3, 16, kernel_size=3, stride=1, padding=1),
            BatchNorm2d(16),
            ReLU(inplace=True),
            MaxPool2d(kernel_size=2, stride=2),
            # Defining another 2D convolution layer
            Conv2d(16, 4, kernel_size=3, stride=1, padding=1),
            BatchNorm2d(4),
            ReLU(inplace=True),
            MaxPool2d(kernel_size=2, stride=2),
        )

        self.linear_layers = Sequential(
            Linear(18480, 1)
        )

    # Defining the forward pass    
    def forward(self, x):
        x = self.cnn_layers(x)
        x = x.view(x.size(0), -1)
        print('here')
        print(x.shape)
        x = self.linear_layers(x)
        return x

# %%
def train_model(net, criterion, optimizer, scheduler, n_epochs):
    for epoch in range(n_epochs):
        net.train()
        tr_loss = 0
        # getting the training set
        for i, data in enumerate(trainLoader, 0):
            #print(data)
            train_x, train_y = data
            x_train, y_train = Variable(train_x), Variable(train_y)

            #print('!!!!!')
            #print(x_train)
            #print('?????')
            #print(y_train)

            # getting the validation set
            #x_val, y_val = Variable(val_x), Variable(val_y)
            # converting the data into GPU format
            if torch.cuda.is_available():
                x_train = x_train.cuda()
                y_train = y_train.cuda()
                #x_val = x_val.cuda()
                #y_val = y_val.cuda()

            # clearing the Gradients of the model parameters
            optimizer.zero_grad()

            # prediction for training and validation set
            output_train = net(x_train)
            #output_val = model(x_val)
            #print(output_train, y_train.float())
            # computing the training and validation loss
            output_train=output_train.squeeze(-1)
            #output_val=output_val.squeeze(-1)
            loss_train = criterion(output_train, y_train.float())
            #loss_val = criterion(output_val, y_val.float())
            #train_losses.append(loss_train)
            #val_losses.append(loss_val)

            # computing the updated weights of all the model parameters
            loss_train.backward()
            optimizer.step()
            tr_loss = loss_train.item()
            # if epoch%2 == 0:
            # printing the validation loss
            print('Epoch : ',epoch+1, '\t', 'loss :', loss_train)
            
    return net

# %%
# loading test images
def test(net):
    test_img = []
    for img_name in tqdm(test_data['track']):
        # defining the image path
        image_path = './img/' + str(img_name) + '.jpg'
        # reading the image
        img = imread(image_path)
        #img = resize(img, (28, 28))
        img = asarray(img)
        # converting the type of pixel to float 32
        img = img.astype('float32')
         # normalizing the pixel values
        img /= 255.0
        # appending the image into the list
        #test_img.append(img)
        #print(img.size())
        img = np.array(img)
        img = img.reshape(1, 3, 220, 338)
        img = torch.tensor(img, dtype=torch.float32,device=device)
        prediction = net(img).cpu().detach().numpy()
        print(i + ': ' + str(prediction[0][0]))
        writer.writerow([i, prediction[0][0]])
        
    '''    
    # converting the list to numpy array
    test_x = np.array(test_img)
    test_x.shape
    
    # converting training images into torch format
    test_x = test_x.reshape(15, 3, 28, 28)
    test_x  = torch.from_numpy(test_x)
    test_x.shape
    '''

# %%
trainData = myDataset()
trainLoader = DataLoader(dataset=trainData, batch_size=5, shuffle=True, num_workers=0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 220/220 [00:00<00:00, 695.81it/s]
# > Found 220 audios...

# %%
#check gpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

#set hyperparameter
EPOCH = 100
LR = 0.01

#resnet18 = models.resnet18(pretrained=True)
#net = resnet18.to(device)
net = Net().to(device)

criterion = MSELoss()
optimizer = Adam(net.parameters(), lr=LR, weight_decay=5e-4)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

net = train_model(net=net, criterion=criterion, optimizer=optimizer,scheduler=exp_lr_scheduler, n_epochs=EPOCH)
# Out:
# cuda:0
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(0.4950, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(17973.2598, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(699.5087, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1774.7294, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(5603.1357, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(6745.4062, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(4589.6270, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1475.9832, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(518.2465, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(261.7629, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1621.8309, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1477.9619, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(2139.7261, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1060.0839, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(768.1995, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(415.3232, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(35.1742, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(168.0650, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(1107.1166, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(558.9487, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(676.8666, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(431.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(329.5872, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(129.9810, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(77.5674, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(72.4474, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(45.8063, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(135.4797, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(249.7294, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(127.1818, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(171.3278, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(162.3956, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(50.7745, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(47.3888, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(28.3519, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(100.9527, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(112.3060, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(123.1256, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(109.4578, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(75.4153, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(9.8861, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor(29.1316, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  1 	 loss : tensor
device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1365, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0561, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0281, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1091, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0436, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0677, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1274, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0137, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1745, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0830, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0307, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1738, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0762, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0592, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1228, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0969, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0666, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0475, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1027, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0540, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0267, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0252, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0409, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0878, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0367, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.1024, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0479, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0668, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0705, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  98 	 loss : tensor(0.0325, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0292, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0311, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0132, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0319, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0206, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0325, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0688, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0684, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0350, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0345, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0054, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0139, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0247, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1247, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0352, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0748, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0799, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0388, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0410, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1100, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0267, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0230, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0369, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0367, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0234, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.4523, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1036, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0500, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0253, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0286, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1550, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1141, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1523, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0205, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1570, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0242, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0485, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.1515, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0658, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  99 	 loss : tensor(0.0258, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.1359, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0794, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0585, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.1136, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0122, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0719, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0627, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0406, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.1028, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0950, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0204, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0820, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0455, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0577, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0105, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0266, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0344, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0548, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0578, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0344, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.2458, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0231, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.2074, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0276, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0261, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0936, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0237, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0714, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0180, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0228, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0256, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0351, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0628, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.1771, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0221, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0354, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0268, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0238, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0110, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0416, device='cuda:0', grad_fn=<MseLossBackward>)
# here
# torch.Size([5, 18480])
# Epoch :  100 	 loss : tensor(0.0559, device='cuda:0', grad_fn=<MseLossBackward>)

# %%
# generating predictions for test set
with torch.no_grad():
    output = test(net=net)

print(output)
#prob = list(softmax.numpy())
#predictions = np.argmax(prob, axis=1)
# Out:
#   0%|                                                                                           | 0/15 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4240\784027361.py in <module>
#       1 # generating predictions for test set
#       2 with torch.no_grad():
# ----> 3     output = test(net=net)
#       4
#       5 print(output)
#
# ~\AppData\Local\Temp\ipykernel_4240\3042383875.py in test(net)
#      19         img = img.reshape(1, 3, 220, 338)
#      20         img = torch.from_numpy(img)
# ---> 21         prediction = net(img).cpu().detach().numpy()
#      22         print(i + ': ' + str(prediction[0][0]))
#      23         writer.writerow([i, prediction[0][0]])
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Temp\ipykernel_4240\58094879.py in forward(self, x)
#      22     # Defining the forward pass
#      23     def forward(self, x):
# ---> 24         x = self.cnn_layers(x)
#      25         x = x.view(x.size(0), -1)
#      26         print('here')
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     117     def forward(self, input):
#     118         for module in self:
# --> 119             input = module(input)
#     120         return input
#     121
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
# --> 399         return self._conv_forward(input, self.weight, self.bias)
#     400
#     401 class Conv3d(_ConvNd):
#
# ~\anaconda3\envs\pytorch\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     394                             _pair(0), self.dilation, self.groups)
#     395         return F.conv2d(input, weight, bias, self.stride,
# --> 396                         self.padding, self.dilation, self.groups)
#     397
#     398     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Input type (torch.FloatTensor) and weight type (torch.cuda.FloatTensor) should be the same

# %%
# replacing the label with prediction
sample_submission['score'] = output.cpu()
sample_submission.head()

# %%
# saving the file
sample_submission.to_csv('submission.csv', index=False)
